# %%
import h5py

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# 2024-04-03 09:33:19.693656: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-03 09:33:19.698405: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-03 09:33:19.772669: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-03 09:33:21.010729: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
mnist=tf.keras.datasets.mnist
(Xtr,ytr),(Xte,yte)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
Xval,Xtr=Xtr[:5000]/255,Xtr[5000:]/255
yval,ytr=ytr[:5000],ytr[5000:]
Xte=Xte/255

# %%
plt.figure(figsize=(15,10))
sns.heatmap(Xtr[0],annot=True,cmap='binary')
plt.show()

# %%
from tensorflow.keras.layers import Flatten as flat, Dense as dense
from tensorflow.keras.models import Sequential as seq
Layers=[
    flat(input_shape=[28,28],name='inputLayer'),
    dense(300,activation='relu',name='hiddenLayer1'),
    dense(100,activation='relu',name='hiddenLayer2'),
    dense(10,activation='softmax',name='outputLayer')
]
model_clf=seq(Layers)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model_clf.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inputLayer (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hiddenLayer1 (Dense)            │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hiddenLayer2 (Dense)            │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ outputLayer (Dense)             │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 266,610 (1.02 MB)
#  Trainable params: 266,610 (1.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
LOSS_FUNC='sparse_categorical_crossentropy'
OPTIMIZER='SGD'
METRICS=['accuracy']
model_clf.compile(loss=LOSS_FUNC,optimizer=OPTIMIZER,metrics=METRICS)

# %%
import time
import os
def get_log_path(log_dir='logs/fit'):
    fileName=time.strftime('log_%Y_%m_%d_%H_%M_%S')
    logs_path=os.path.join(log_dir,fileName)
    print(f'Saving logs at {logs_path}')
    return logs_path
log_dir=get_log_path()
tb_cb=tf.keras.callbacks.TensorBoard(log_dir=log_dir)
# Out:
# Saving logs at logs/fit/log_2024_04_03_09_34_34

# %%
print(os.getcwd())
# Out:
# /home/jovyan/work/Neural Networks

# %%
early_stopping_cb=tf.keras.callbacks.EarlyStopping(patience=5,restore_best_weights=True)

# %%
CKPT_path='Model_ckpt.keras'
checkpointing_cb=tf.keras.callbacks.ModelCheckpoint(filepath=CKPT_path,save_best_only=True)

# %%
EPOCHS=30
VAL_SET=(Xval,yval)

# %%
history=model_clf.fit(Xtr,ytr,epochs=EPOCHS,validation_data=VAL_SET,callbacks=[tb_cb,early_stopping_cb,checkpointing_cb])
# Out:
# Epoch 1/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7447 - loss: 0.9901 - val_accuracy: 0.9150 - val_loss: 0.3081
# Epoch 2/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9145 - loss: 0.3024 - val_accuracy: 0.9330 - val_loss: 0.2436
# Epoch 3/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9296 - loss: 0.2450 - val_accuracy: 0.9410 - val_loss: 0.2051
# Epoch 4/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9411 - loss: 0.2054 - val_accuracy: 0.9512 - val_loss: 0.1815
# Epoch 5/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.